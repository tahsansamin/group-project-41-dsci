# %%
#github link: https://github.com/tahsansamin/group-project-41-dsci.git
library(tidyverse)

# %% [markdown]
# ## DSCI 100 Group Project
# Group members(UBC student number): Tahsan Samin (15680358), ...., ...., ....

# %% [markdown]
# ### Title: ......

# %% [markdown]
# ### Introduction

# %% [markdown]
# ### Methods and Results

# %% [markdown]
# For our project KNN classification will be used be

# %% [markdown]
# #### Loading and downloading dataset

# %%
players <- read_csv("https://raw.githubusercontent.com/tahsansamin/group-project-41-dsci/refs/heads/main/players.csv")
is_na <- sum(is.na(players))
is_na

# %% [markdown]
# The NA values will be removed because they are so few and it is unlikely to have an effect on the data

# %%
players <- drop_na(players)
is_na_now <- sum(is.na(players))

# %%
is_na_now

# %%
head(players)

# %% [markdown]
# The next step is to select only the relevant target variable and predictor variables (number of hours played, age and subscription status)

# %%
players <- players |> select(played_hours, Age, subscribe)
head(players)
# next steps for wrangling: class imbalance in subscribe, outliers in played_hours

# %% [markdown]
# ### Discussion

# %% [markdown]
# ### References(optional)
