# %%
#github link: https://github.com/tahsansamin/group-project-41-dsci.git

# %% [markdown]
# ## DSCI 100 Group Project
# Group members(UBC student number): Tahsan Samin (15680358), ...., ...., ....

# %% [markdown]
# ### Title: ......

# %% [markdown]
# ### Introduction

# %% [markdown]
# ### Methods and Results

# %% [markdown]
# ### Discussion

# %% [markdown]
# ### References(optional)
