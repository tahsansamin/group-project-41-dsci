# %%
#install.packages(c("tidymodels"))
#install.packages("kknn")

library(tidyverse)
library(repr)
library(tidymodels)
library(themis)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.6     ✔ rsample      1.2.1
# ✔ dials        1.3.0     ✔ tune         1.1.2
# ✔ infer        1.0.7     ✔ workflows    1.1.4
# ✔ modeldata    1.4.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.2.1     ✔ yardstick    1.3.1
# ✔ recipes      1.1.0
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Dig deeper into tidy modeling with R at https://www.tmwr.org

# %% [markdown]
# ## DSCI 100 Group Project
# Group members(UBC student number): Tahsan Samin (15680358), ...., ...., ....

# %% [markdown]
# ### Title: ......

# %% [markdown]
# ### Introduction

# %% [markdown]
# ### Methods and Results
# For our project KNN classification will be used because our selected player variables (age of the players and number of hours played by the player) are numerical and our target variable (subscription status to a game related newspaper) is categorical. The players dataset was used instead of the sessions dataset because the former has all the relevant predictor variables and the target variable. From the players dataset the rows with NA values will be removed and only the number of hours played, the age of the player and the subscription status variables will be selected. The data will be split into 75% training data and 25% testing data. 5 fold cross validation with a range of Ks will be used to select the model based on the highest cross validation accuracy. We will use 5 folds because of computational efficiency.
# #### Loading and wrangling the dataset into a tidy format
# The dataset already satisfies all criteria for being tidy. During the exploratory data analysis, we noticed that two of the observations had NA values. We decided to drop the two observations with NA values because they are so few that it is unlikely to cause loss of valuable information. The two NA observations are NA in the age column. Looking at their reading for the number of hours played(0.1 hours and 0.2 hours), the readings do not appear to be extreme cases, further proving that dropping NA values would not cause loss of valuable data. We will also change the subscription status into the factor data type to make it suitable for KNN classification.

# %%
players <- read_csv("https://raw.githubusercontent.com/tahsansamin/group-project-41-dsci/refs/heads/main/players.csv")
is_na <- sum(is.na(players))
is_na
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# [1] 2

# %%
narows <- players[!complete.cases(players),]
narows
# Out:
#   experience subscribe
# 1 Regular    TRUE
# 2 Pro        TRUE
#   hashedEmail                                                      played_hours
# 1 7d71c49cbbce8dcf0276b2bfecfa2d16f22cb31a4024556d6085884298f2ee8d 0.1
# 2 d9473710057f7d42f36570f0be83817a4eea614029ff90cf50d8889cdd729d11 0.2
#   name  gender       Age
# 1 Devin Two-Spirited NA
# 2 Ahmed Other        NA

# %%
players <- drop_na(players)
players <- players |> mutate(subscribe = as_factor(subscribe))

# %% [markdown]
# #### Summary of the players dataset
# We will now perform a statistical summary of the numerical variables in the players dataset. Right away it is clear that we may be dealing with a few outliers for the number of hours played variable because it has such a large range from 0 hours to 223.10 hours but such a small mean of 5.85 hours. This is something that should be kept in mind.

# %%
summary_stats_players <- players |> 
                summarise(min_Age = min(Age, na.rm = TRUE),max_Age = max(Age, na.rm = TRUE),mean_age = mean(Age, na.rm = TRUE), min_played_hours = min(played_hours),max_played_hours = max(played_hours), 
                         , mean_played_hours = mean(played_hours, na.rm = TRUE))

# %% [markdown]
# #### Players.csv
#
# | Variable | Minimum | Maximum | Mean |
# | -------- | ------- | -------- | -----|
# | Age | 9.00 | 58.00 | 21.14 |
# | played_hours | 0.00 | 223.10 | 5.85 |

# %% [markdown]
# #### Visualization of the players dataset
# Below is a scatter plot of the number of hours played versus the age of the player. We log scaled the y axis to make the data points more visible. As was suspected before there are a few outliers for the number of hours played. For now we will do the KNN classification algorithm with these outliers to see if they actually have a negative impact on our results. Furthermore, there seems to be a class imbalance with more observations for true subscription statuses. For now we will attempt the KNN classification algorithm without accounting for this to try and see if it actually negatively impacts our results.

# %%
figure_1 <- players |>
            ggplot(aes(x = Age, y= log1p(played_hours), color = subscribe)) +
            geom_point() +
            labs(x = "Age of the Player", y = "Logarithm of (1 plus number of hours played)", title = "(Figure 1) Number of Hours played against the Age of Player") +
            theme(text = element_text(size = 14)) 
#log1p was added after discussion with a TA on how to make both variables on comparable scales.
#standardising and centering the variables did not work in making the variables comparable so log1p was suggested by the TA
figure_1
# Out:
# plot without title

# %% [markdown]
# #### Data analysis
# ##### Splitting the dataset into training and testing splits

# %%
set.seed(9999) 
game_split <- initial_split(players, prop = 0.75, strata = subscribe)  
game_train <- training(game_split)
game_test <- testing(game_split)
game_train
# Out:
#     experience subscribe
# 1   Veteran    FALSE
# 2   Amateur    FALSE
# 3   Amateur    FALSE
# 4   Amateur    FALSE
# 5   Veteran    FALSE
# 6   Veteran    FALSE
# 7   Amateur    FALSE
# 8   Veteran    FALSE
# 9   Beginner   FALSE
# 10  Regular    FALSE
# 11  Amateur    FALSE
# 12  Beginner   FALSE
# 13  Beginner   FALSE
# 14  Amateur    FALSE
# 15  Regular    FALSE
# 16  Veteran    FALSE
# 17  Amateur    FALSE
# 18  Regular    FALSE
# 19  Veteran    FALSE
# 20  Beginner   FALSE
# 21  Beginner   FALSE
# 22  Amateur    FALSE
# 23  Regular    FALSE
# 24  Regular    FALSE
# 25  Veteran    FALSE
# 26  Amateur    FALSE
# 27  Amateur    FALSE
# 28  Veteran    FALSE
# 29  Beginner   FALSE
# 30  Veteran    FALSE
# ⋮   ⋮          ⋮
# 116 Beginner   TRUE
# 117 Regular    TRUE
# 118 Veteran    TRUE
# 119 Veteran    TRUE
# 120 Veteran    TRUE
# 121 Regular    TRUE
# 122 Beginner   TRUE
# 123 Beginner   TRUE
# 124 Pro        TRUE
# 125 Amateur    TRUE
# 126 Amateur    TRUE
# 127 Beginner   TRUE
# 128 Beginner   TRUE
# 129 Amateur    TRUE
# 130 Amateur    TRUE
# 131 Regular    TRUE
# 132 Beginner   TRUE
# 133 Beginner   TRUE
# 134 Pro        TRUE
# 135 Regular    TRUE
# 136 Regular    TRUE
# 137 Veteran    TRUE
# 138 Amateur    TRUE
# 139 Amateur    TRUE
# 140 Veteran    TRUE
# 141 Amateur    TRUE
# 142 Amateur    TRUE
# 143 Amateur    TRUE
# 144 Beginner   TRUE
# 145 Amateur    TRUE
#     hashedEmail
# 1   b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28
# 2   1d2371d8a35c8831034b25bda8764539ab7db0f63938696917c447128a2540dd
# 3   2313a06afe47eacc28ff55adf6f072e7d12b0d12d7cbae29656f9029ec72bb53
# 4   200db0417ee70863c7e2a0f214c737476fb86de5869d0b907a077d726357e687
# 5   f8acd26a5e452b682b9f8b20108caef1ee2e745efe08e95806980bd2388a3fea
# 6   951e54f7376e2b2f0915e9e3646c701af4a2fe839385b13f9e0084b08f8070bd
# 7   df6a1201c9c638aff1df8aeaf459a5b0a00aa04824936ee0305f5c275352c647
# 8   88247d9a46fc214a12485dcbcbb03a8ddebfe8c1ec5fe209cd660147625c8e62
# 9   fa7d496b2f74c51ec70395bd8397b49f97a3ce8d7ba7e08887d82ec0008137a7
# 129   0.0        Mikael    Male              19
# 130   1.2        Aaron     Non-binary        17
# 131 178.2        Piper     Female            19
# 132   0.0        Ji-Yeon   Male              22
# 133   0.0        Taylor    Male              24
# 134   0.6        Arlo      Male              19
# 135   0.5        Xia       Female            20
# 136   0.1        Rupert    Male              21
# 137   0.0        Saif      Agender           20
# 138   0.3        Joaquim   Male              17
# 139   0.4        Charlie   Two-Spirited      17
# 140   0.1        Finnian   Non-binary        17
# 141   0.8        Hunter    Female            22
# 142  32.0        Sidney    Male              22
# 143   0.0        Jasper    Male              17
# 144   0.0        Lina      Female            17
# 145   0.0        Rhys      Male              20

# %% [markdown]
# Next we will create the recipe to be applied on our dataset for KNN classification.

# %%
game_recipe <- recipe(subscribe ~ played_hours + Age , data = game_train) |>
   step_scale(all_predictors()) |>
   step_center(all_predictors())

# %% [markdown]
# Next we will create our model specification and prepare the data for cross validation. A range of values from 1 to 15 was selected for tuning the number of neighbors because the range seems appropriate for our dataset size and it would also be computationally efficient.

# %%
set.seed(1234) 
game_vfold <- vfold_cv(game_train, v = 5, strata = subscribe)
k_vals <- tibble(neighbors = seq(from = 1, to = 15, by = 1))
knn_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |>
            set_engine("kknn") |>
            set_mode("classification")
knn_tune
# Out:
# K-Nearest Neighbor Model Specification (classification)
#
# Main Arguments:
#   neighbors = tune()
#   weight_func = rectangular
#
# Computational engine: kknn

# %% [markdown]
# We will now actually perform the 5 cross fold validation.

# %%
set.seed(2456)
knn_results <- workflow() |>
      add_recipe(game_recipe) |>
      add_model(knn_tune) |>
      tune_grid(resamples = game_vfold, grid = k_vals) |>
      collect_metrics()
knn_results
# Out:
#    neighbors .metric  .estimator mean      n std_err    .config
# 1   1        accuracy binary     0.5593596 5 0.03233644 Preprocessor1_Model01
# 2   1        roc_auc  binary     0.5781926 5 0.03619044 Preprocessor1_Model01
# 3   2        accuracy binary     0.5455665 5 0.02398160 Preprocessor1_Model02
# 4   2        roc_auc  binary     0.6016659 5 0.02662140 Preprocessor1_Model02
# 5   3        accuracy binary     0.5929064 5 0.01750648 Preprocessor1_Model03
# 6   3        roc_auc  binary     0.5906347 5 0.03608753 Preprocessor1_Model03
# 7   4        accuracy binary     0.6205090 5 0.02914624 Preprocessor1_Model04
# 8   4        roc_auc  binary     0.5839788 5 0.05340661 Preprocessor1_Model04
# 9   5        accuracy binary     0.6069458 5 0.03509799 Preprocessor1_Model05
# 10  5        roc_auc  binary     0.5961541 5 0.05308012 Preprocessor1_Model05
# 11  6        accuracy binary     0.6069458 5 0.03509799 Preprocessor1_Model06
# 12  6        roc_auc  binary     0.6069419 5 0.04503813 Preprocessor1_Model06
# 13  7        accuracy binary     0.6416749 5 0.04074329 Preprocessor1_Model07
# 14  7        roc_auc  binary     0.5839556 5 0.05229996 Preprocessor1_Model07
# 15  8        accuracy binary     0.6209852 5 0.04414123 Preprocessor1_Model08
# 16  8        roc_auc  binary     0.5833527 5 0.05846146 Preprocessor1_Model08
# 17  9        accuracy binary     0.6078818 5 0.05170889 Preprocessor1_Model09
# 18  9        roc_auc  binary     0.5646529 5 0.04897554 Preprocessor1_Model09
# 19 10        accuracy binary     0.5943186 5 0.05741150 Preprocessor1_Model10
# 20 10        roc_auc  binary     0.5525974 5 0.05637775 Preprocessor1_Model10
# 21 11        accuracy binary     0.6007389 5 0.05098939 Preprocessor1_Model11
# 22 11        roc_auc  binary     0.5653061 5 0.05702141 Preprocessor1_Model11
# 23 12        accuracy binary     0.6074056 5 0.04804753 Preprocessor1_Model12
# 24 12        roc_auc  binary     0.5483186 5 0.05192939 Preprocessor1_Model12
# 25 13        accuracy binary     0.6904598 5 0.03424709 Preprocessor1_Model13
# 26 13        roc_auc  binary     0.5499188 5 0.05524034 Preprocessor1_Model13
# 27 14        accuracy binary     0.6904598 5 0.03424709 Preprocessor1_Model14
# 28 14        roc_auc  binary     0.5649737 5 0.05471154 Preprocessor1_Model14
# 29 15        accuracy binary     0.7116092 5 0.03678269 Preprocessor1_Model15
# 30 15        roc_auc  binary     0.5499575 5 0.05711840 Preprocessor1_Model15

# %%
accuracies <- knn_results |> 
      filter(.metric == "accuracy")

accuracy_versus_k <- ggplot(accuracies, aes(x = neighbors, y = mean))+
      geom_point() +
      geom_line() +
      labs(x = "Neighbors", y = "Accuracy Estimate") +
      scale_x_continuous(breaks = seq(0, 15, by = 1)) +  # adjusting the x-axis
      scale_y_continuous(limits = c(0.4, 1.0)) # adjusting the y-axis

accuracy_versus_k
# Out:
# plot without title

# %% [markdown]
# A K value of 15 neighbors seems to give the highest accuracy with a value just above 70%.
# We will next re train a new KNN classification model with K = 15 and use that to perform predictions on the testing dataset to evaluate our model performance.

# %%
set.seed(9999) 
new_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = 15) |>
       set_engine("kknn") |>
       set_mode("classification")

game_fit <- workflow() |>
             add_recipe(game_recipe) |>
             add_model(new_spec) |>
            fit(data = game_train)
game_fit
# Out:
# ══ Workflow [trained] ══════════════════════════════════════════════════════════
# Preprocessor: Recipe
# Model: nearest_neighbor()
#
# ── Preprocessor ────────────────────────────────────────────────────────────────
# 2 Recipe Steps
#
# • step_scale()
# • step_center()
#
# ── Model ───────────────────────────────────────────────────────────────────────
#
# Call:
# kknn::train.kknn(formula = ..y ~ ., data = data, ks = min_rows(15,     data, 5), kernel = ~"rectangular")
#
# Type of response variable: nominal
# Minimal misclassification: 0.2689655
# Best kernel: rectangular
# Best k: 15

# %%
set.seed(9999) 


game_predictions <- predict(game_fit, game_test) |>
                        bind_cols(game_test)

game_metrics <- game_predictions |> metrics(truth = subscribe, estimate = .pred_class)

game_conf_mat <- game_predictions |>
                        conf_mat(truth = subscribe, estimate = .pred_class) 
game_metrics
game_conf_mat
# Out:
#   .metric  .estimator .estimate
# 1 accuracy binary      0.6530612
# 2 kap      binary     -0.1426612
#           Truth
# Prediction FALSE TRUE
#      FALSE     0    4
#      TRUE     13   32

# %% [markdown]
# The model appears to be performing well with an accuracy performance of 65% ,but this is not enough. It looks like the issue of class imbalance is really affecting our model because it did not predict any of the false subscription statuses as actually being false. Let's try this again by oversampling the observations with false subscription statuses. We will only upsample on the training data because we still need the original test dataset to evaluate whether our upsampling had any positive effects.

# %%
new_game_recipe <- recipe(subscribe ~ played_hours + Age, data = game_train) |>
  step_upsample(subscribe, over_ratio = 1, skip = FALSE) |>
  prep()

game_train <- bake(new_game_recipe, game_train)

# %% [markdown]
# Since upsampling changes the structure of our dataset, we will need to perform cross fold validation again. For cross validation we will increase the range of values of K because it looks like we are achieving higher accuracy for higher values of K.

# %%
set.seed(1234) 
new_game_vfold <- vfold_cv(game_train, v = 5, strata = subscribe)
new_knn_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |>
            set_engine("kknn") |>
            set_mode("classification")

# %%
set.seed(2456)
new_knn_results <- workflow() |>
      add_recipe(game_recipe) |>
      add_model(new_knn_tune) |>
      tune_grid(resamples = new_game_vfold, grid = tibble(neighbors = seq(from = 1, to = 25, by = 1))) |>
      collect_metrics()
new_knn_results
# Out:
#    neighbors .metric  .estimator mean      n std_err    .config
# 1   1        accuracy binary     0.7110390 5 0.03290114 Preprocessor1_Model01
# 2   1        roc_auc  binary     0.7110390 5 0.03290114 Preprocessor1_Model01
# 3   2        accuracy binary     0.7062771 5 0.03479669 Preprocessor1_Model02
# 4   2        roc_auc  binary     0.7180534 5 0.03767807 Preprocessor1_Model02
# 5   3        accuracy binary     0.6541126 5 0.04393673 Preprocessor1_Model03
# 6   3        roc_auc  binary     0.6928028 5 0.04441316 Preprocessor1_Model03
# 7   4        accuracy binary     0.6777056 5 0.04308175 Preprocessor1_Model04
# 8   4        roc_auc  binary     0.6873302 5 0.03905215 Preprocessor1_Model04
# 9   5        accuracy binary     0.6645022 5 0.02091854 Preprocessor1_Model05
# 10  5        roc_auc  binary     0.6802805 5 0.04609528 Preprocessor1_Model05
# 11  6        accuracy binary     0.6645022 5 0.02091854 Preprocessor1_Model06
# 12  6        roc_auc  binary     0.6748890 5 0.04805610 Preprocessor1_Model06
# 13  7        accuracy binary     0.6690476 5 0.03067643 Preprocessor1_Model07
# 14  7        roc_auc  binary     0.6650475 5 0.04632328 Preprocessor1_Model07
# 15  8        accuracy binary     0.6690476 5 0.03067643 Preprocessor1_Model08
# 16  8        roc_auc  binary     0.6605377 5 0.05113842 Preprocessor1_Model08
# 17  9        accuracy binary     0.6357143 5 0.03273268 Preprocessor1_Model09
# 18  9        roc_auc  binary     0.6514824 5 0.04775474 Preprocessor1_Model09
# 19 10        accuracy binary     0.6357143 5 0.03273268 Preprocessor1_Model10
# 20 10        roc_auc  binary     0.6258789 5 0.05657735 Preprocessor1_Model10
# 21 11        accuracy binary     0.6452381 5 0.03113499 Preprocessor1_Model11
# 22 11        roc_auc  binary     0.6279146 5 0.05258290 Preprocessor1_Model11
# 23 12        accuracy binary     0.6406926 5 0.02527004 Preprocessor1_Model12
# 24 12        roc_auc  binary     0.6192524 5 0.05346694 Preprocessor1_Model12
# 25 13        accuracy binary     0.6270563 5 0.01530381 Preprocessor1_Model13
# 26 13        roc_auc  binary     0.6103381 5 0.04676749 Preprocessor1_Model13
# 27 14        accuracy binary     0.6220779 5 0.01909920 Preprocessor1_Model14
# 28 14        roc_auc  binary     0.6053546 5 0.05421622 Preprocessor1_Model14
# 29 15        accuracy binary     0.6077922 5 0.02653083 Preprocessor1_Model15
# 30 15        roc_auc  binary     0.5989599 5 0.05176665 Preprocessor1_Model15
# 31 16        accuracy binary     0.6075758 5 0.03092209 Preprocessor1_Model16
# 32 16        roc_auc  binary     0.6065286 5 0.05127111 Preprocessor1_Model16
# 33 17        accuracy binary     0.5982684 5 0.02824323 Preprocessor1_Model17
# 34 17        roc_auc  binary     0.6137999 5 0.04786963 Preprocessor1_Model17
# 35 18        accuracy binary     0.5982684 5 0.02824323 Preprocessor1_Model18
# 36 18        roc_auc  binary     0.6159817 5 0.04683901 Preprocessor1_Model18
# 37 19        accuracy binary     0.5980519 5 0.03150001 Preprocessor1_Model19
# 38 19        roc_auc  binary     0.6120261 5 0.04807433 Preprocessor1_Model19
# 39 20        accuracy binary     0.6028139 5 0.02895098 Preprocessor1_Model20
# 40 20        roc_auc  binary     0.6171155 5 0.04644700 Preprocessor1_Model20
# 41 21        accuracy binary     0.5935065 5 0.02564181 Preprocessor1_Model21
# 42 21        roc_auc  binary     0.6257473 5 0.04205110 Preprocessor1_Model21
# 43 22        accuracy binary     0.5889610 5 0.02185075 Preprocessor1_Model22
# 44 22        roc_auc  binary     0.6284684 5 0.04039955 Preprocessor1_Model22
# 45 23        accuracy binary     0.5837662 5 0.04086498 Preprocessor1_Model23
# 46 23        roc_auc  binary     0.6302473 5 0.04505720 Preprocessor1_Model23
# 47 24        accuracy binary     0.5837662 5 0.04086498 Preprocessor1_Model24
# 48 24        roc_auc  binary     0.6336135 5 0.04689118 Preprocessor1_Model24
# 49 25        accuracy binary     0.5787879 5 0.04434114 Preprocessor1_Model25
# 50 25        roc_auc  binary     0.6356239 5 0.04238498 Preprocessor1_Model25

# %%
new_accuracies <- new_knn_results |> 
      filter(.metric == "accuracy")

new_accuracy_versus_k <- ggplot(new_accuracies, aes(x = neighbors, y = mean))+
      geom_point() +
      geom_line() +
      labs(x = "Neighbors", y = "Accuracy Estimate") +
      scale_x_continuous(breaks = seq(0, 20, by = 1)) +  # adjusting the x-axis
      scale_y_continuous(limits = c(0.4, 1.0)) # adjusting the y-axis

new_accuracy_versus_k
# Out:
# plot without title

# %% [markdown]
# It looks like the highest performance comes from K = 2, excluding the performance for K =1.

# %%
set.seed(9999) 
newer_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = 2) |>
       set_engine("kknn") |>
       set_mode("classification")

new_game_fit <- workflow() |>
             add_recipe(game_recipe) |>
             add_model(newer_spec) |>
            fit(data = game_train)
new_game_fit
# Out:
# ══ Workflow [trained] ══════════════════════════════════════════════════════════
# Preprocessor: Recipe
# Model: nearest_neighbor()
#
# ── Preprocessor ────────────────────────────────────────────────────────────────
# 2 Recipe Steps
#
# • step_scale()
# • step_center()
#
# ── Model ───────────────────────────────────────────────────────────────────────
#
# Call:
# kknn::train.kknn(formula = ..y ~ ., data = data, ks = min_rows(2,     data, 5), kernel = ~"rectangular")
#
# Type of response variable: nominal
# Minimal misclassification: 0.2971698
# Best kernel: rectangular
# Best k: 2

# %%
set.seed(9999) 


new_game_predictions <- predict(new_game_fit, game_test) |>
                        bind_cols(game_test)

new_game_metrics <- new_game_predictions |> metrics(truth = subscribe, estimate = .pred_class)

new_game_conf_mat <- new_game_predictions |>
                        conf_mat(truth = subscribe, estimate = .pred_class) 
new_game_metrics
new_game_conf_mat
# Out:
#   .metric  .estimator .estimate
# 1 accuracy binary      0.42857143
# 2 kap      binary     -0.09062003
#           Truth
# Prediction FALSE TRUE
#      FALSE     6   21
#      TRUE      7   15

# %% [markdown]
# - plans
# - Not best method(KNN deals very poorly with imbalance)
# - Data not enough more data to train it
# - Classes imbalanced
# - Model too simple
# - overfit/underfit

# %% [markdown]
# ### Discussion

# %% [markdown]
# Discussion:
# summarize what you found
# - We found that this data could not predict. not learning meaningfully.
# - model is worse than random guessing
# - add more data.
# - try more powerful model like random forest, logistic regression, svm, dec tree
# - add class weightages or undersample.
# discuss whether this is what you expected to find
# - NO. We expected higher accuracy. Positive cohensomething. More than 60% accuracy at minimum. reasons: using supervised learning.
# discuss what impact could such findings have
# - increase advertising to specific age groups or demographics.
# - increased user engagement. e.g high user players would like more frequent updates.
# -
# discuss what future questions could this lead to

# %% [markdown]
# ### References(optional)
